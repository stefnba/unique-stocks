# %%
from utils.parallel.concurrent import proces_paralell

tasks = [1, 2, 3, 4, 5]


def task(n):
    print(n)
    raise Exception("error")
    return n


proces_paralell(task=task, iterable=tasks)
# Out:
# Start execution.
# 1
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[8], line 12
#       8     raise Exception("error")
#       9     return n
# ---> 12 proces_paralell(task=task, iterable=tasks)
#
# File ~/Development/projects/unique-stocks/services/pipelines/include/utils/parallel/concurrent.py:19, in proces_paralell(task, iterable, max_workers, *args, **kwargs)
#      16 future = executor.submit(task, i, *args, **kwargs)
#      18 if future.exception():
# ---> 19     raise Exception(f"Exception for task with {i}: {future.exception()}")
#      21 else:
#      22     result = future.result()
#
# Exception: Exception for task with 1: error
